# %% [markdown]
# ### Data pre-processing

# %%
import pandas as pd
import numpy as np
import os.path
import os
import re

# %%
#importing files
parent_dir = '/home/Time Series/dataset'

xlsx_files = [os.path.join(parent_dir, xlsx) for xlsx in os.listdir(parent_dir) if os.path.isfile(os.path.join(parent_dir, xlsx)) and xlsx.endswith('.xlsx')] 

li = []
   
for filename in xlsx_files:
    df = pd.read_excel(filename,index_col=None,header=[1],usecols=["Name","Age","Sex","Area","Date Of Reporting"],
                        parse_dates=['Date Of Reporting'])
    df['Date Of Reporting'] = pd.to_datetime(df['Date Of Reporting'],errors = 'coerce')
    li.append(df)  

data = pd.concat(li)

#drop rows with no names & date of reporting
data = data[data['Name'].notna()]
data = data[data['Date Of Reporting'].notna()]
data = data.reset_index(drop=True)

# %%
data.head(10)
# Out:
#            Name  Age Sex           Area Date Of Reporting
# 0  UNNIKRISHNAN   17   M           CORP        2013-01-01
# 1      AMAL RAJ   11   M           CORP        2013-01-01
# 2         AKHIL   12   M           CORP        2013-01-01
# 3         ANUJA   18   F  BALARAMAPURAM        2013-01-01
# 4          BINU   38   M  NEYYATTINKARA        2013-01-01
# 5         SUDHA   58   F        MUKKOLA        2013-01-01
# 6      MUHAMMED  1.5   M      VIZHINJAM        2013-01-01
# 7    THANKAMANI   43   F      POOZHANAD        2013-01-01
# 8          ANJU   15   F           CORP        2013-01-01
# 9       RAJAMMA   50   F  BALARAMAPURAM        2013-01-01

# %%
data.shape
# Out:
# (17845, 5)

# %%
data.isnull().sum()
# Out:
# Name                   0
# Age                  448
# Sex                  561
# Area                  32
# Date Of Reporting      0
# dtype: int64

# %%
#remove html-tags, and non-alphabetic characters 
def keepAlpha(sentence):
    alpha_sent = ""
    for word in sentence.split():
        alpha_word = re.sub('[^a-z A-Z]+', ' ', word)
        alpha_sent += alpha_word
        alpha_sent += " "
    alpha_sent = alpha_sent.strip()
    return alpha_sent

#remove any punctuation or special characters
def cleanPunc(sentence): 
    cleaned = re.sub(r'[?|!|\'|"|#]',r'',sentence)
    cleaned = re.sub(r'[.|,|)|(|\|/]',r' ',cleaned)
    cleaned = cleaned.strip()
    cleaned = cleaned.replace("\n"," ")
    return cleaned

#remove white space  
def whitespace(sentence):
    space_removed = " ".join(sentence.split())
    return space_removed

# %%
data['Sex'] = data['Sex'].str.upper()
data.Sex.unique()
# Out:
# array(['M', 'F', nan, 'DENGUE', ' M', ' F', 'M,', ',M', ',', 'FM',
#        'FEMALE', 'MALE', 'FEMALETHATL', 'MONTHS', 'FEMALE ', 'M  ',
#        '48 FEMALE', 'C', 'M ', ' MALE', ' FEMALE', '34 MALE'],
#       dtype=object)

# %%
data['Sex']=data['Sex'].fillna("")

# %%
data['Sex'] = data['Sex'].apply(keepAlpha)

# %%
data['Sex'] = data['Sex'].apply(cleanPunc)

# %%
data.loc[data['Sex'].isin(['FM', 'FEMALETHATL', 'MONTHS', 'C','DENGUE'])]
# Out:
#                  Name  Age          Sex         Area Date Of Reporting
# 583             KUMAR  Con       DENGUE  Corporation        2013-04-18
# 10244         sandhya   35           FM   KILIMANOOR        2017-05-23
# 10245           subha   43           FM     VEMBAYAM        2017-05-23
# 10246           latha   46           FM     VEMBAYAM        2017-05-23
# 10247         aswathy   26           FM   KILIMANOOR        2017-05-23
# 10248            nisa   34           FM     NAGAROOR        2017-05-23
# 10249   bulkees beevi   75           FM  KIZHUVILLOM        2017-05-23
# 10250          animol   43           FM      ANAKUDY        2017-05-23
# 10252          sheela   61           FM  PUTHENTHOPE        2017-05-23
# 10253       praseetha   28           FM     KOLLAYIL        2017-05-23
# 10256         lathika   37           FM    THOLICODE        2017-05-23
# 10257         swaliha   15           FM   NEDUMANGAD        2017-05-23
# ...

# %%
data.replace({'Sex' : { 'MALE' : 'M','FEMALE':'F','FM':'F','FEMALETHATL':'F','MONTHS':'F'}},inplace=True)

# %%
data["Sex"].iloc[583]='M'
data["Sex"].iloc[15127]='F'
data["Sex"].iloc[15128]='M'
data["Sex"].iloc[15470]='M'
data.replace({'Sex' : { '' : np.nan}},inplace=True)
data['Sex']=data['Sex'].astype('category')
# Out:
# /home/j/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
data.Sex.unique()
# Out:
# [M, F, NaN]
# Categories (2, object): [M, F]

# %%
data.Age.unique()
# Out:
# array([17, 11, 12, 18, 38, 58, 1.5, 43, 15, 50, 6, 5, 60, 29, 2, 22, 30,
#        48, 21, 16, 51, 8, 3.5, 36, 28, 46, 20, 52, 37, 27, 63, 39, 14, 31,
#        '6mnts', 40, 34, 32, 62, 54, 78, 61, 19, 3, 45, 44, 33, 26, 13, 35,
#        47, 65, 24, 76, 4.5, 7, 49, 56, 10, 2.5, nan, 55, 6.5, 11.5, 23,
#        42, 67, 75, 9, 6.75, 4, 64, 41, 25, 57, 70, 1, 4.75, 72, 53, '10m',
#        68, 59, '8 MONTHS', '10M', '11m', '23,', '72,', 87, 'Con', '51/2',
#        85, '33/4', 92, datetime.datetime(2013, 7, 12, 0, 0), 73, 8.5, 9.5,
#        '1.5 yrs', 5.5, 0.11, '2m', 74, 66, 'F', 'M', 88, 7.5, 84, '7m',
#        '5month', 69, 77, 323, 71, 86, 94, 3.75, 82, '3 ½ ', '8m',
#        '10 Months', '6m', 80, 10.5, 90, '7M', ' 5 ½ ', 1.75, '9m', 2.7,
#        '8 MON', '2y6m', '7y11m', '4y10m', '4y4m', '5y8m', '8yrs 5M  ',
#        '8yrs 11M', '7Y9M', '7y9m', '5y14d', '9y3m', '3y11m', '2y7m',
#        '5y10m', '7 MONTHS', '9y11m', '10y2m', 79, '2yrs 11mths', '23Y',
# ...

# %%
data['Age_']=data.Age.str.extract('(^\d*)')
null_idx = data['Age_'].isnull()
data.loc[null_idx, 'Age_'] = data['Age']
data['Age_'] = pd.to_numeric(data['Age_'], errors='coerce')
data['Age_'] = data['Age_'].round()

# %%
data.Age_.unique()
# Out:
# array([ 17.,  11.,  12.,  18.,  38.,  58.,   2.,  43.,  15.,  50.,   6.,
#          5.,  60.,  29.,  22.,  30.,  48.,  21.,  16.,  51.,   8.,   4.,
#         36.,  28.,  46.,  20.,  52.,  37.,  27.,  63.,  39.,  14.,  31.,
#         40.,  34.,  32.,  62.,  54.,  78.,  61.,  19.,   3.,  45.,  44.,
#         33.,  26.,  13.,  35.,  47.,  65.,  24.,  76.,   7.,  49.,  56.,
#         10.,  nan,  55.,  23.,  42.,  67.,  75.,   9.,  64.,  41.,  25.,
#         57.,  70.,   1.,  72.,  53.,  68.,  59.,  87.,  85.,  92.,  73.,
#          0.,  74.,  66.,  88.,  84.,  69.,  77., 323.,  71.,  86.,  94.,
#         82.,  80.,  90.,  79.,  89., 590.,  83.,  81.])

# %%
data.loc[data['Age_'].isin(['590', '0', '323'])]
# Out:
#                       Name   Age Sex           Area Date Of Reporting   Age_
# 857                 ALEENA  0.11   F    PHC Mukkola        2013-05-17    0.0
# 1706            RAJ KUMAR,   323   M            COR        2013-06-17  323.0
# 8880          ABDUL MAJEED   590   M    VEERANAKAVU        2017-04-25  590.0
# 10571           SARASWATHY     0   F        VITHURA        2017-05-30    0.0
# 12313            Krishnmma     0   F    Thiruvallam        2017-06-23    0.0
# 12332              Vaisakh     0   M           Corp        2017-06-23    0.0
# 12336         Sharathgopan     0   M   Vilavoorkkal        2017-06-23    0.0
# 12341       Sudarsanakumar     0   M  Chettivilakam        2017-06-23    0.0
# 12342       Sudarsanakumar     0   M  Chettivilakam        2017-06-23    0.0
# 12855       ALFA -8 MONTHS     0   F           CORP        2017-03-07    0.0
# 12968     SANTHOSH   KUMAR     0   M           CORP        2017-04-07    0.0
# ...

# %%
data["Age_"].iloc[857]=11
data["Age_"].iloc[1706]=32
data["Age_"].iloc[8880]=59
data["Age_"].iloc[12855]=1
data["Age_"].iloc[13018]=1
data["Age_"].iloc[13778]=1
data["Age_"].iloc[13948]=10
data["Age_"].iloc[14646]=10
data["Age_"].iloc[14988]=1
data["Age_"].iloc[14995]=1
data["Age_"].iloc[15905]=1
data.replace({'Age_' : { 0 : np.nan}},inplace=True)

# %%
data.Age_.unique()
# Out:
# array([17., 11., 12., 18., 38., 58.,  2., 43., 15., 50.,  6.,  5., 60.,
#        29., 22., 30., 48., 21., 16., 51.,  8.,  4., 36., 28., 46., 20.,
#        52., 37., 27., 63., 39., 14., 31., 40., 34., 32., 62., 54., 78.,
#        61., 19.,  3., 45., 44., 33., 26., 13., 35., 47., 65., 24., 76.,
#         7., 49., 56., 10., nan, 55., 23., 42., 67., 75.,  9., 64., 41.,
#        25., 57., 70.,  1., 72., 53., 68., 59., 87., 85., 92., 73., 74.,
#        66., 88., 84., 69., 77., 71., 86., 94., 82., 80., 90., 79., 89.,
#        83., 81.])

# %%
data.drop('Age', axis=1, inplace=True)
data = data.rename(index=str,columns={'Age_':'Age'})

# %%
data.head()
# Out:
#            Name Sex           Area Date Of Reporting   Age
# 0  UNNIKRISHNAN   M           CORP        2013-01-01  17.0
# 1      AMAL RAJ   M           CORP        2013-01-01  11.0
# 2         AKHIL   M           CORP        2013-01-01  12.0
# 3         ANUJA   F  BALARAMAPURAM        2013-01-01  18.0
# 4          BINU   M  NEYYATTINKARA        2013-01-01  38.0

# %%
data['Area'] = data['Area'].str.lower()
data['Area'] = data['Area'].fillna("")
rm_words = {'chc','phc','thq','thqe','thqu','zone','[nemomzone]','rhc','th',
            '( dengue negative)','tvm','[nemam]','[ nemom]','thqh','mch','repeat'}
data['Area'] = data['Area'].str.split(' ').apply(lambda x: ' '.join(k for k in x if k not in rm_words))
data['Area'] = data['Area'].apply(whitespace)

# %%
data.tail(10)
# Out:
#                  Name Sex           Area Date Of Reporting   Age
# 17835          JALAJA   F      karakulam        2018-12-18  40.0
# 17836       SREEKUMAR   M           corp        2018-12-18  53.0
# 17837         VIJAYAN   M       vilappil        2018-12-19  36.0
# 17838          Subash   M       malayadi        2018-12-20  35.0
# 17839         Shibin    M       panavoor        2018-12-22   2.0
# 17840           Kiran   M  chettivilakam        2018-12-24  22.0
# 17841  Rajendran Nair   M     pangappara        2018-12-24  46.0
# 17842       Sathyaraj   M        kallara        2018-12-27  26.0
# 17843      Vipin Nath   M           anad        2018-12-27  37.0
# 17844   Amelia Mary,    F           veli        2018-12-29   8.0

# %%
rm_area = ['( stayed in bangalore )','(out of area tamil nadu)','cant traced out','not identified','not traced','out of area(kollam)']
data = data[~data['Area'].isin(rm_area)]

# %%
data['Area'].value_counts()
# Out:
# corp                             3617
# corporation                      1036
# cor                               845
# karakulam                         666
# vizhinjam                         636
# pallichal                         634
# nemom                             546
# vattiyoorkavu                     437
# kalliyoor                         426
# balaramapuram                     342
# poonthura                         329
# vilappil                          304
# mukkola                           301
# aruvikkara                        289
# thiruvallom                       265
# pangappara                        235
# thiruvallam                       228
# attingal                          214
# valiyathura                       188
# veli                              186
# kottukal                          184
# puthenthope                       160
# venpakal                          151
# chettivilakom                     150
# vattiyoorkkavu                    150
# ...

# %%
area_repl = {'cor' :'corporation',
            'c0rp':'corporation',
            'corp':'corporation',
            'corpoartion':'corporation',
            'crporation':'corporation',
            'con':'corporation',
            'cop':'corporation',
            'coporation':'corporation',
            'coprp':'corporation',
            'cor veli':'corporation',
            'cor[ nemom]' :'corporation',
            'cor[kadakampally]' :'corporation',
            'cororation' :'corporation',
            'corporaton' :'corporation',
            'corportaion' :'corporation',
            'corpotation' :'corporation',
            'kazhakootam [cor]':'corporation',
            'punnakkamugal [cor]':'corporation',
            'palayam [cor]':'corporation',
            'vattiyoorkavu':'vattiyoorkkavu',
            'vattiyoorkav':'vattiyoorkkavu',
            'vattiyiiravu':'vattiyoorkkavu',
            'thiruvallom':'thiruvallam',
            'thamalam':'thiruvallam',
            'thiruvalam':'thiruvallam',
            'thiruvallmom':'thiruvallam',
            'thiruvillam':'thiruvallam',
            'thriuvallom':'thiruvallam',
            'thriuvallam':'thiruvallam',
            'pangappara':'pangapara',
            'chettivilakom':'chettivilakam',
            'chetivilakom':'chettivilakam',
            'chettivlakom':'chettivilakam',
            'malayinkeel':'malayinkeezhu',
            'malayinkeezh':'malayinkeezhu',
            'malayinkil':'malayinkeezhu',
            'vilavoorkal':'vilavoorkkal',
            'kadakampalli':'kadakampally',
            '{repeat} kadakampalli':'kadakampally',
            'nedumancaud':'nedumangad',
            'nedumangadu':'nedumangad',
            'nedumangaud':'nedumangad',
            'kizhuvillom':'kizhuvillam',
            'chirayinkeezh':'chirayinkeezhu',
            'vettor':'vettoor',
            'peroorkada [cor]':'peroorkada',
            'varkala':'varkkala',
            'adayamin':'adayamon',
            'adayaon':'adayamon',
            'anakudi':'anakudy',
            'andoorkkoanam':'andoorkonam',
            'andoorkkonam':'andoorkonam',
            'anjutheng':'anjuthengu',
            'aruikkara':'aruvikkara',
            'aruvikara':'aruvikkara',
            'aruvikkra':'aruvikkara',
            'aruvukara':'aruvikkara',
            'arvikkara':'aruvikkara',
            'aryanadu':'aryanad',
            'atingal':'attingal',
            'attigal':'attingal',
            'balaramapurm':'balaramapuram',
            'balarampuram':'balaramapuram',
            'balramapuram':'balaramapuram',
            'blaramapuram':'balaramapuram',
            'bharathanoor':'bhrathannoor',
            'bharthanoor' :'bhrathannoor',
            'bhrathannoor':'bhrathannoor',
            'chiayinkeel':'chirayinkeezhu',
            'chirayin keezhu':'chirayinkeezhu',
            'chirayinkeel':'chirayinkeezhu',
            'chirayinkezhu':'chirayinkeezhu',
            'chirayinkil':'chirayinkeezhu',
            'chriayinkeezhu':'chirayinkeezhu',
            'kaakulam':'karakulam',
            'karakulm':'karakulam',
            'karkulam':'karakulam',
            'karumkulam':'karakulam',
            'kadaakampalli':'kadakampally',
            'kadakakampalli':'kadakampally',
            'kadakam pally':'kadakampally',
            'kadakam-pally':'kadakampally',
            'kadakamapalli':'kadakampally',
            'kadakamaplly':'kadakampally',
            'kadakamappli':'kadakampally',
            'kadakamplli':'kadakampally',
            'kadakanpally':'kadakampally',
            'kadakmpalli':'kadakampally',
            'kdakam pally':'kadakampally',
            'kadakompalli':'kadakampally',
            'kaliiyoor':'kalliyoor',
            'kallioor':'kalliyoor',
            'kallara(out of area tamilnad)':'kallara',
            'kallicade':'kallikkad',
            'kallikaad':'kallikkad',
            'kallikad':'kallikkad',
            'kallikad new':'kallikkad',
            'kallikade':'kallikkad',
            'kallikadu':'kallikkad',
            'kallikkad new':'kallikkad',
            'kallikkade':'kallikkad',
            'kallikkadu':'kallikkad',
            'kallikkadu new':'kallikkad',
            'kanjaramkulam':'kanjiramkulam',
            'karakulm':'karakulam',
            'karkulam':'karakulam',
            'karumkulam':'karakulam',
            'karavara,':'karamana',
            'karavaram':'karamana',
            'karod':'karode',
            'katakada':'kattakkada',
            'katakkada':'kattakkada',
            'kattakada':'kattakkada',
            'keezhattigal':'keezhattingal',
            'kilimanoor':'kilimanoor',
            'kizhivillam':'kizhuvillam',
            'kizhuvilam':'kizhuvillam',
            'kollayill':'kollayil',
            'kulathur':'kulathoor',
            'kunnathukal':'kunnatyhukal',
            'kutichal':'kuttichal',
            'madavoor ( dengue negative)':'madavoor',
            'malayainkeezh':'malayinkeezhu',
            'malayikeezhu':'malayinkeezhu',
            'malayimkil':'malayinkeezhu',
            'malayin keezhu':'malayinkeezhu',
            'malyinkeezhu':'malayinkeezhu',
            'mlayinkeezhu':'malayinkeezhu',
            'managalapuram':'mangalapuram',
            'mangalapularam':'mangalapuram',
            'manglapuram':'mangalapuram',
            'manickal':'manikkal',
            'mannickal':'manikkal',
            'maranaloor':'maranalloor',
            'maranelloor':'maranalloor',
            'maranellor':'maranalloor',
            'maraneloor':'maranalloor',
            'marnalloor':'maranalloor',
            'mdakkal':'mudakkal',
            'navaikaulam':'navaikulam',
            'nedumanagad':'nedumangad',
            'nedumanagadu':'nedumangad',
            'nedumanangad':'nedumangad',
            'nedumangade':'nedumangad',
            'nedumanghad':'nedumangad',
            'nedummangade':'nedumangad',
            'nemon':'nemom',
            'nemomzone':'nemom',
            'nemam':'nemom',
            'nrmom':'nemom',
            'neyyattinakara':'neyyattinkara',
            'neyyattikara':'neyyattinkara',
            'pallichal(repeat)':'pallichal',
            'pallickal':'pallichal',
            'pallikkal':'pallichal',
            'parasala':'parassala',
            'panagppara':'pangapara',
            'panagappara':'pangapara',
            'pangappra':'pangapara',
            'parassalazone':'parassala',
            'parasuvaikal':'parassala',
            'parasuvaikkal':'parassala',
            'parasuvakkal':'parassala',
            'parsuvaikkal':'parassala',
            'peringammala':'peringamala',
            'peerumkadavila':'perumkadavila',
            'perookkada':'peroorkkada',
            'peroorkada':'peroorkkada',
            'perunkadavila':'perumkadavila',
            'perumpahuthoor':'perumpazhuthoor',
            'perumpazhthoor':'perumpazhuthoor',
            'perumpazhuthur':'perumpazhuthoor',
            'plode':'palode',
            'prassala':'parassala',
            'poojapura':'poojappura',
            'poothura':'poonthura',
            'poozhanadu':'poozhanad',
            'poozhanand':'poozhanad',
            'poozhandu':'poozhanad',
            'poozhznad':'poozhanad',
            'pozhiyooor':'pozhiyoor',
            'puithenthope':'puthenthope',
            'puthanthope':'puthenthope',
            'puthen thoppu':'puthenthope',
            'puthenthoppe':'puthenthope',
            'puthenthoppu':'puthenthope',
            'puthentope':'puthenthope',
            'puthethope':'puthenthope',
            'pulllampara':'pullampara',
            'puthukkuruchi':'puthukurichi',
            'puthukkuruchy':'puthukurichi',
            'puthukurichy':'puthukurichi',
            'puthukuruchi':'puthukurichi',
            'puthukuruchy':'puthukurichi',
            'puthukurussi':'puthukurichi',
            'puthuurichi':'puthukurichi',
            'tholikode':'tholicode',
            'thonackal':'thonnakkal',
            'thonakal':'thonnakkal',
            'thonakkal':'thonnakkal',
            'thonnakal':'thonnakkal',
            'thonnipara':'thonnippara',
            'uzhamalackkal':'uzhamalakkal',
            'vakkam':'vakkom',
            'valiathura':'valiyathura',
            'valiatura':'valiyathura',
            'valiayathura':'valiyathura',
            'valiyathira':'valiyathura',
            'valliyathura':'valiyathura',
            'valyathura':'valiyathura',
            'viliyathura':'valiyathura',
            'vallakadave [cor]':'vallakadavu',
            'vamanpuram':'vamanapuram',
            'vambayam':'vembayam',
            'varakal':'varkkala',
            'varakala':'varkkala',
            'varkala':'varkkala',
            'vattiyookavu':'vattiyoorkkavu',
            'vattiyooravu':'vattiyoorkkavu',
            'vattiyoorkave':'vattiyoorkkavu',
            'vattiyorkavu':'vattiyoorkkavu',
            'vattiyyorkkavu':'vattiyoorkkavu',
            'vatttiyoorkavu':'vattiyoorkkavu',
            'veeranakav':'veeranakavu',
            'veeranakave':'veeranakavu',
            'veernakavu':'veeranakavu',
            'vellanadu':'vellanad',
            'vellaradar':'vellarada',
            'vellarda':'vellarada',
            'velllanad':'vellanad',
            'venapakl':'venpakal',
            'venpakl':'venpakal',
            'venpkal':'venpakal',
            'vetoor':'vettoor',
            'vialvoorkal':'vilavoorkkal',
            'vilapiil':'vilappil',
            'vilappil (vilavoorkkal)':'vilavoorkkal',
            'vilppil':'vilappil',
            'vilvoorkal':'vilavoorkkal',
            'vilvoorkkal':'vilavoorkkal',
            'vithra':'vithura',
            'vizhijam':'vizhinjam',
            'vizhinjma':'vizhinjam',
            'vizinjam':'vizhinjam',
            'vzihinjam':'vizhinjam',
             'arayanadu':'aryanad',
             'anchuthengu':'anjuthengu',
             'bharathannoor':'bhrathannoor',
             'cheiniyoor':'cherunniyoor',
             'general hospital, trivandrum':'corporation',
             'kallacade':'kallikkad',
             'kallra':'kallara',
             'kilimanoor.':'kilimanoor',
             'kuttukal':'kottukal',
             'manaikkal':'manikkal',
             'panvoor':'panavoor',
             'peroorkada':'peroorkkada',
             'perukadavila':'peroorkkada',
             'peerumathura':'perumathura',
             'repet vilavoorkkal':'vilavoorkkal',
             'thonippara':'thonnippara'
            }

# %%
data['Area'] = data['Area'].replace(area_repl)
data['Area'] = data['Area'].str.upper()
data.replace({'Area' : { '' : np.nan}},inplace=True)

# %%
data['Name'] = data['Name'].apply(cleanPunc)
data['Name'] = data['Name'].apply(keepAlpha)  
data['Name'] = data['Name'].apply(whitespace)
data['Name'] = data['Name'].str.upper()
data.sort_values(by=['Date Of Reporting'], inplace=True)
data = data[['Name', 'Sex', 'Age', 'Area', 'Date Of Reporting']]
data = data.reset_index(drop=True)
data.isnull().sum()
# Out:
# Name                   0
# Sex                  572
# Age                  535
# Area                  37
# Date Of Reporting      0
# dtype: int64

# %%
data.head(10)
# Out:
#            Name Sex   Age           Area Date Of Reporting
# 0  UNNIKRISHNAN   M  17.0    CORPORATION        2013-01-01
# 1      MURAMMIL   M   6.0    ANDOORKONAM        2013-01-01
# 2       RAJAMMA   F  50.0  BALARAMAPURAM        2013-01-01
# 3          ANJU   F  15.0    CORPORATION        2013-01-01
# 4    THANKAMANI   F  43.0      POOZHANAD        2013-01-01
# 5      MUHAMMED   M   2.0      VIZHINJAM        2013-01-01
# 6         NOORA   F   5.0  NEYYATTINKARA        2013-01-01
# 7          BINU   M  38.0  NEYYATTINKARA        2013-01-01
# 8         ANUJA   F  18.0  BALARAMAPURAM        2013-01-01
# 9         AKHIL   M  12.0    CORPORATION        2013-01-01

# %%
data.to_csv('/home/Time Series/data.csv', sep=';',index=False)
